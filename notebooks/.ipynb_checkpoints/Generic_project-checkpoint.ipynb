# %% [markdown]
# # Generic project template

# %% [markdown]
# This Jupyter notebook is a template to use for :
# - data exploration

# %% [markdown]
# # Imports

# %% [markdown]
# All the necessary libraries and classes are imported from here.

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler, MinMaxScaler, OneHotEncoder, OrdinalEncoder

# %% [markdown]
# # Retrieve data

# %%
path_to_data = '../raw_data/'
data = pd.read_csv(path_to_data + 'train.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# # Explore data

# %% [markdown]
# ## Drop columns (preliminary) like user_index, user_id, Names, etc...

# %% [markdown]
# Drop columns that will not be useful immediatly (like user_id, user_index, Names, Surnames, etc...)

# %%
data = data.drop(columns='Id')
data.head(1)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
#
# [1 rows x 80 columns]

# %% [markdown]
# ## Exploration

# %% [markdown]
# ### Shape

# %%
# Shape
data.shape
# Out:
# (1460, 80)

# %% [markdown]
# ### Columns

# %%
#Columns
data.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ### Statistics

# %%
#Statistics
data.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000   383.500000     0.000000  ...
# 75%    2000.000000   2004.000000   166.000000   712.250000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1474.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# ### Info

# %%
# Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   object
#  21  RoofMatl       1460 non-null   object
#  22  Exterior1st    1460 non-null   object
#  23  Exterior2nd    1460 non-null   object
#  24  MasVnrType     1452 non-null   object
#  25  MasVnrArea     1452 non-null   float64
#  26  ExterQual      1460 non-null   object
#  27  ExterCond      1460 non-null   object
#  28  Foundation     1460 non-null   object
#  29  BsmtQual       1423 non-null   object
#  30  BsmtCond       1423 non-null   object
#  31  BsmtExposure   1422 non-null   object
#  32  BsmtFinType1   1423 non-null   object
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1422 non-null   object
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   object
#  39  HeatingQC      1460 non-null   object
#  40  CentralAir     1460 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   object
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   object
#  55  Fireplaces     1460 non-null   int64
#  56  FireplaceQu    770 non-null    object
#  57  GarageType     1379 non-null   object
#  58  GarageYrBlt    1379 non-null   float64
#  59  GarageFinish   1379 non-null   object
#  60  GarageCars     1460 non-null   int64
#  61  GarageArea     1460 non-null   int64
#  62  GarageQual     1379 non-null   object
#  63  GarageCond     1379 non-null   object
#  64  PavedDrive     1460 non-null   object
#  65  WoodDeckSF     1460 non-null   int64
#  66  OpenPorchSF    1460 non-null   int64
#  67  EnclosedPorch  1460 non-null   int64
#  68  3SsnPorch      1460 non-null   int64
#  69  ScreenPorch    1460 non-null   int64
#  70  PoolArea       1460 non-null   int64
#  71  PoolQC         7 non-null      object
#  72  Fence          281 non-null    object
#  73  MiscFeature    54 non-null     object
#  74  MiscVal        1460 non-null   int64
#  75  MoSold         1460 non-null   int64
#  76  YrSold         1460 non-null   int64
#  77  SaleType       1460 non-null   object
#  78  SaleCondition  1460 non-null   object
#  79  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 912.6+ KB

# %% [markdown]
# ### Data distributions

# %%
#Data distributions
data.hist(bins = 50, figsize = (20,10))
plt.show()

# %% [markdown]
# ### Correlations

# %% [markdown]
# #### Correlation Heatmap

# %%
# Heatmap of pairwise correlations
correlation_matrix = data.corr()
column_names = correlation_matrix.columns
sns.heatmap(correlation_matrix, xticklabels=column_names, yticklabels=column_names,cmap= "bwr");

# %% [markdown]
# #### Correlations between features

# %%
# Correlation between features

correlation_matrix = data.corr()

# Converting the correlation matrix into a DataFrame
corr_df = correlation_matrix.stack().reset_index()

# Renaming the columns
corr_df.columns = ['feature_1','feature_2', 'correlation']

# Remove "self correlations"
no_self_correlation = (corr_df['feature_1'] != corr_df['feature_2'])
corr_df = corr_df[no_self_correlation]

corr_df['absolute_correlation'] = np.abs(corr_df['correlation'])

corr_df.sort_values(by="absolute_correlation", ascending=False, inplace = True)
corr_df
# Out:
#          feature_1     feature_2  correlation  absolute_correlation
# 987     GarageArea    GarageCars     0.882475              0.882475
# 951     GarageCars    GarageArea     0.882475              0.882475
# 209      YearBuilt   GarageYrBlt     0.825667              0.825667
# 893    GarageYrBlt     YearBuilt     0.825667              0.825667
# 829   TotRmsAbvGrd     GrLivArea     0.825489              0.825489
# ...            ...           ...          ...                   ...
# 1143     3SsnPorch       MiscVal     0.000354              0.000354
# 640   BsmtHalfBath   TotalBsmtSF    -0.000315              0.000315
# 424    TotalBsmtSF  BsmtHalfBath    -0.000315              0.000315
# 622   BsmtFullBath     3SsnPorch    -0.000106              0.000106
# 1126     3SsnPorch  BsmtFullBath    -0.000106              0.000106
#
# [1332 rows x 4 columns]

# %% [markdown]
# #### Correlation between target and features

# %% [markdown]
# **/!\ HUMAN INPUT FOR TARGET NAME /!\**

# %%
# Correlation between target and features
target_name = "SalePrice"
corr_df[corr_df["feature_1"] == target_name].head(10)
# Out:
#       feature_1     feature_2  correlation  absolute_correlation
# 1335  SalePrice   OverallQual     0.790982              0.790982
# 1347  SalePrice     GrLivArea     0.708624              0.708624
# 1357  SalePrice    GarageCars     0.640409              0.640409
# 1358  SalePrice    GarageArea     0.623431              0.623431
# 1343  SalePrice   TotalBsmtSF     0.613581              0.613581
# 1344  SalePrice      1stFlrSF     0.605852              0.605852
# 1350  SalePrice      FullBath     0.560664              0.560664
# 1354  SalePrice  TotRmsAbvGrd     0.533723              0.533723
# 1337  SalePrice     YearBuilt     0.522897              0.522897
# 1338  SalePrice  YearRemodAdd     0.507101              0.507101

# %% [markdown]
# #### Scatter_matrix

# %%
# Extract list of high correlated features to target
number_feat_to_extract = 6
extract_df = corr_df[corr_df["feature_1"] == target_name]\
                    .head(number_feat_to_extract)[['feature_2']]\
                    .values.tolist()

# Attributes
attributes = []

#Format a list with the attributes
for element in extract_df:
    attributes.append(element[0])

# Insert target in attributes
attributes.append(target_name)

# %%
#Plot scatter_matrix
scatter_matrix(data[attributes], figsize= (12,8))
plt.show()

# %% [markdown]
# # Prepare the dataset

# %% [markdown]
# ## Duplicates

# %%
# Check number of rows before removing duplicates
print(f"Number of rows : {len(data)}") 

# Compute the number of duplicated rows
print(f"Number of duplicated rows : {data.duplicated().sum()}") 

# Remove duplicates
# data = data.drop_duplicates()
# Out:
# Number of rows : 1460
# Number of duplicated rows : 0

# %% [markdown]
# ## Missing values

# %%
# Counting the percentage of NaN for each column
#NaN percentage for each column
missing_data = data.isnull().sum().sort_values(ascending=False)/len(data)*100 

# missing_data
# print("Missing data in percentage : ");

missing_data[missing_data > 0];

# %%
#Create a df showing the percentage of missing data
missing_values_df = pd.DataFrame(missing_data, columns = ['Percent_missing'])
missing_values_df = missing_values_df[missing_values_df['Percent_missing'] > 0]

missing_values_df = missing_values_df.reset_index()\
                    .rename(columns = {'index' : 'features'})

# Missing values columns (with percentage of missing values > 0)
missing_values_columns = missing_values_df['features'].values.tolist()

#Retrieve types of columns with missing data as a Dataframe
type_missing_values_df = pd.DataFrame(data[missing_values_columns].dtypes, columns=['Type'])
type_missing_values_df = type_missing_values_df.reset_index()\
                        .rename(columns = {'index' : 'features'})

#Merge features, feature type and percentage of missing values
missing_values_df = pd.merge(missing_values_df, type_missing_values_df)
missing_values_df
# Out:
#         features  Percent_missing     Type
# 0         PoolQC        99.520548   object
# 1    MiscFeature        96.301370   object
# 2          Alley        93.767123   object
# 3          Fence        80.753425   object
# 4    FireplaceQu        47.260274   object
# 5    LotFrontage        17.739726  float64
# 6    GarageYrBlt         5.547945  float64
# 7     GarageCond         5.547945   object
# 8     GarageType         5.547945   object
# 9   GarageFinish         5.547945   object
# 10    GarageQual         5.547945   object
# 11  BsmtExposure         2.602740   object
# 12  BsmtFinType2         2.602740   object
# 13      BsmtCond         2.534247   object
# 14      BsmtQual         2.534247   object
# 15  BsmtFinType1         2.534247   object
# 16    MasVnrArea         0.547945  float64
# 17    MasVnrType         0.547945   object
# 18    Electrical         0.068493   object

# %%
#Missing value columns
print(f"Length of features with missing values : {len(missing_values_columns)}\n")
print(f"columns with values missing : {missing_values_columns}")
# Out:
# Length of features with missing values : 19
#
# columns with values missing : ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'LotFrontage', 'GarageYrBlt', 'GarageCond', 'GarageType', 'GarageFinish', 'GarageQual', 'BsmtExposure', 'BsmtFinType2', 'BsmtCond', 'BsmtQual', 'BsmtFinType1', 'MasVnrArea', 'MasVnrType', 'Electrical']

# %% [markdown]
# ### Missing values : Categorical columns

# %%
#Categorical features with missing values
categorical_feat_missing = missing_values_df[missing_values_df.Type == 'object']['features'].values.tolist()

print(f"Length of Categorical features with missing values : {len(categorical_feat_missing)}\n")
print(f"Remaining categorical columns with values missing : {categorical_feat_missing}")
# Out:
# Length of Categorical features with missing values : 16
#
# Remaining categorical columns with values missing : ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'GarageCond', 'GarageType', 'GarageFinish', 'GarageQual', 'BsmtExposure', 'BsmtFinType2', 'BsmtCond', 'BsmtQual', 'BsmtFinType1', 'MasVnrType', 'Electrical']

# %% [markdown]
# #### Missing values : drop categorical columns

# %% [markdown]
# **/!\ Check if NANs correspond to an actual value/ has a meaning within each column before dropping it.**

# %%
# Select categorical features with more than 90% of missing values => create a list
condition = (missing_values_df['Percent_missing'] > 90) & (missing_values_df['Type']== 'object')
cat_columns_missing_high = missing_values_df[condition]['features'].values.tolist()

print(f"Categorical columns with high rate of values missing : {cat_columns_missing_high}")
# Out:
# Categorical columns with high rate of values missing : ['PoolQC', 'MiscFeature', 'Alley']

# %% [markdown]
# **/!\ Check if NANs correspond to an actual value/ has a meaning within each column before dropping it.**

# %% [markdown]
# **If nans do not represent something meaningful in the documentation of the features, we can drop it (if rate > 90%)**

# %% [markdown]
# **/!\ HUMAN INPUT TO KEEP RELEVANT COLUMN BELOW /!\**

# %%
# FULL STOP !!!!!!!!!!!

# %%
# Nans in the following columns have a meaning. Do not drop the following columns !!!!!
cat_columns_missing_high.remove('Alley') #nans in Alley are meaningful. Do not drop 'Alley'

# Ratio of missing values is way too high, let's drop these features
data.drop(columns= cat_columns_missing_high, inplace=True) 
data.head(1)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig  ... 3SsnPorch ScreenPorch PoolArea Fence  \
# 0         Lvl    AllPub    Inside  ...         0           0        0   NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
#
# [1 rows x 78 columns]

# %%
# Remove dropped columns from list of total categorical features with missing values
for col in cat_columns_missing_high:
    categorical_feat_missing.remove(col)
    
print(f"Length of Categorical features with missing values : {len(categorical_feat_missing)}\n")
print(f"Remaining categorical columns with values missing : {categorical_feat_missing}")
# Out:
# Length of Categorical features with missing values : 14
#
# Remaining categorical columns with values missing : ['Alley', 'Fence', 'FireplaceQu', 'GarageCond', 'GarageType', 'GarageFinish', 'GarageQual', 'BsmtExposure', 'BsmtFinType2', 'BsmtCond', 'BsmtQual', 'BsmtFinType1', 'MasVnrType', 'Electrical']

# %% [markdown]
# #### Missing values : replace nans by 'NA' (categorical cols)

# %%
# Check unique values of categorical columns with missing values
for col in categorical_feat_missing:
    print(f'--- {col} -----------------------------------------------\n')
    print(f'- Unique values of {col} : {data[col].unique()}\n')   
    print('-----------------------------------------------------------')
# Out:
# --- Alley -----------------------------------------------
#
# - Unique values of Alley : [nan 'Grvl' 'Pave']
#
# -----------------------------------------------------------
# --- Fence -----------------------------------------------
#
# - Unique values of Fence : [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
#
# -----------------------------------------------------------
# --- FireplaceQu -----------------------------------------------
#
# - Unique values of FireplaceQu : [nan 'TA' 'Gd' 'Fa' 'Ex' 'Po']
#
# -----------------------------------------------------------
# --- GarageCond -----------------------------------------------
#
# - Unique values of GarageCond : ['TA' 'Fa' nan 'Gd' 'Po' 'Ex']
#
# -----------------------------------------------------------
# --- GarageType -----------------------------------------------
#
# - Unique values of GarageType : ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
#
# -----------------------------------------------------------
# --- GarageFinish -----------------------------------------------
#
# - Unique values of GarageFinish : ['RFn' 'Unf' 'Fin' nan]
#
# -----------------------------------------------------------
# --- GarageQual -----------------------------------------------
#
# - Unique values of GarageQual : ['TA' 'Fa' 'Gd' nan 'Ex' 'Po']
#
# -----------------------------------------------------------
# --- BsmtExposure -----------------------------------------------
#
# - Unique values of BsmtExposure : ['No' 'Gd' 'Mn' 'Av' nan]
#
# -----------------------------------------------------------
# --- BsmtFinType2 -----------------------------------------------
#
# - Unique values of BsmtFinType2 : ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ']
#
# -----------------------------------------------------------
# --- BsmtCond -----------------------------------------------
#
# - Unique values of BsmtCond : ['TA' 'Gd' nan 'Fa' 'Po']
#
# -----------------------------------------------------------
# --- BsmtQual -----------------------------------------------
#
# - Unique values of BsmtQual : ['Gd' 'TA' 'Ex' nan 'Fa']
#
# -----------------------------------------------------------
# --- BsmtFinType1 -----------------------------------------------
#
# - Unique values of BsmtFinType1 : ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']
#
# -----------------------------------------------------------
# --- MasVnrType -----------------------------------------------
#
# - Unique values of MasVnrType : ['BrkFace' 'None' 'Stone' 'BrkCmn' nan]
#
# -----------------------------------------------------------
# --- Electrical -----------------------------------------------
#
# - Unique values of Electrical : ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]
#
# -----------------------------------------------------------

# %% [markdown]
# Ca we replace nans by NA ?

# %% [markdown]
# **/!\ Check, for each feature, if nan to be replaced by 'NA' (or another default value)**

# %% [markdown]
# **/!\ HUMAN INPUT FOR CHOOSING COLUMNS TO REPLACE MEANINGFUL NAN TO NA /!\**

# %%
# FULL STOP !!!!!!!!!!!

# %%
#List the columns whose nans have to be replaced by NA
columns_replace_by_NA = ['Alley', 'Fence',
                         'FireplaceQu', 'GarageType', 
                         'GarageFinish','GarageQual',
                         'GarageCond','BsmtFinType2',
                         'BsmtExposure','BsmtFinType1',
                         'BsmtQual','BsmtCond']

# %%
#Replace nans by NA in designated columns
for col in columns_replace_by_NA:
    print(f'--- {col} -----------------------------------------------\n')
    print(f'- Unique values of {col} : {data[col].unique()}\n')   
    print( '- Replacing np.nan by NA\n')     
    data[col].replace(np.nan, "NA", inplace=True)
    print(f'- Unique values of {col} : {data[col].unique()}\n')   
    print(f'- Value_counts of {col} :\n') 
    print(data[col].value_counts())
    print('-----------------------------------------------------------')
# Out:
# --- Alley -----------------------------------------------
#
# - Unique values of Alley : [nan 'Grvl' 'Pave']
#
# - Replacing np.nan by NA
#
# - Unique values of Alley : ['NA' 'Grvl' 'Pave']
#
# - Value_counts of Alley :
#
# NA      1369
# Grvl      50
# Pave      41
# Name: Alley, dtype: int64
# -----------------------------------------------------------
# --- Fence -----------------------------------------------
#
# - Unique values of Fence : [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
#
# - Replacing np.nan by NA
#
# - Unique values of Fence : ['NA' 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
#
# - Value_counts of Fence :
#
# NA       1179
# MnPrv     157
# GdPrv      59
# GdWo       54
# MnWw       11
# Name: Fence, dtype: int64
# -----------------------------------------------------------
# --- FireplaceQu -----------------------------------------------
#
# - Unique values of FireplaceQu : [nan 'TA' 'Gd' 'Fa' 'Ex' 'Po']
#
# - Replacing np.nan by NA
#
# - Unique values of FireplaceQu : ['NA' 'TA' 'Gd' 'Fa' 'Ex' 'Po']
#
# - Value_counts of FireplaceQu :
#
# NA    690
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64
# -----------------------------------------------------------
# --- GarageType -----------------------------------------------
#
# - Unique values of GarageType : ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
#
# - Replacing np.nan by NA
#
# - Unique values of GarageType : ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' 'NA' 'Basment' '2Types']
#
# - Value_counts of GarageType :
#
# Attchd     870
# Detchd     387
# BuiltIn     88
# NA          81
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64
# -----------------------------------------------------------
# --- GarageFinish -----------------------------------------------
#
# - Unique values of GarageFinish : ['RFn' 'Unf' 'Fin' nan]
#
# - Replacing np.nan by NA
#
# - Unique values of GarageFinish : ['RFn' 'Unf' 'Fin' 'NA']
#
# - Value_counts of GarageFinish :
#
# Unf    605
# RFn    422
# Fin    352
# NA      81
# Name: GarageFinish, dtype: int64
# -----------------------------------------------------------
# --- GarageQual -----------------------------------------------
#
# - Unique values of GarageQual : ['TA' 'Fa' 'Gd' nan 'Ex' 'Po']
#
# - Replacing np.nan by NA
#
# - Unique values of GarageQual : ['TA' 'Fa' 'Gd' 'NA' 'Ex' 'Po']
#
# - Value_counts of GarageQual :
#
# TA    1311
# NA      81
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: GarageQual, dtype: int64
# -----------------------------------------------------------
# --- GarageCond -----------------------------------------------
#
# - Unique values of GarageCond : ['TA' 'Fa' nan 'Gd' 'Po' 'Ex']
#
# - Replacing np.nan by NA
#
# - Unique values of GarageCond : ['TA' 'Fa' 'NA' 'Gd' 'Po' 'Ex']
#
# - Value_counts of GarageCond :
#
# TA    1326
# NA      81
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64
# -----------------------------------------------------------
# --- BsmtFinType2 -----------------------------------------------
#
# - Unique values of BsmtFinType2 : ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ']
#
# - Replacing np.nan by NA
#
# - Unique values of BsmtFinType2 : ['Unf' 'BLQ' 'NA' 'ALQ' 'Rec' 'LwQ' 'GLQ']
#
# - Value_counts of BsmtFinType2 :
#
# Unf    1256
# Rec      54
# LwQ      46
# NA       38
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
# -----------------------------------------------------------
# --- BsmtExposure -----------------------------------------------
#
# - Unique values of BsmtExposure : ['No' 'Gd' 'Mn' 'Av' nan]
#
# - Replacing np.nan by NA
#
# - Unique values of BsmtExposure : ['No' 'Gd' 'Mn' 'Av' 'NA']
#
# - Value_counts of BsmtExposure :
#
# No    953
# Av    221
# Gd    134
# Mn    114
# NA     38
# Name: BsmtExposure, dtype: int64
# -----------------------------------------------------------
# --- BsmtFinType1 -----------------------------------------------
#
# - Unique values of BsmtFinType1 : ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']
#
# - Replacing np.nan by NA
#
# - Unique values of BsmtFinType1 : ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' 'NA' 'LwQ']
#
# - Value_counts of BsmtFinType1 :
#
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# NA      37
# Name: BsmtFinType1, dtype: int64
# -----------------------------------------------------------
# --- BsmtQual -----------------------------------------------
#
# - Unique values of BsmtQual : ['Gd' 'TA' 'Ex' nan 'Fa']
#
# - Replacing np.nan by NA
#
# - Unique values of BsmtQual : ['Gd' 'TA' 'Ex' 'NA' 'Fa']
#
# - Value_counts of BsmtQual :
#
# TA    649
# Gd    618
# Ex    121
# NA     37
# Fa     35
# Name: BsmtQual, dtype: int64
# -----------------------------------------------------------
# --- BsmtCond -----------------------------------------------
#
# - Unique values of BsmtCond : ['TA' 'Gd' nan 'Fa' 'Po']
#
# - Replacing np.nan by NA
#
# - Unique values of BsmtCond : ['TA' 'Gd' 'NA' 'Fa' 'Po']
#
# - Value_counts of BsmtCond :
#
# TA    1311
# Gd      65
# Fa      45
# NA      37
# Po       2
# Name: BsmtCond, dtype: int64
# -----------------------------------------------------------

# %%
# Remove processed columns from list of total categorical features with missing values
for col in columns_replace_by_NA:
    categorical_feat_missing.remove(col)
    
print(f"Length of Categorical features with missing values : {len(categorical_feat_missing)}")
print(f"Remaining categorical columns with values missing : {categorical_feat_missing}")
# Out:
# Length of Categorical features with missing values : 2
# Remaining categorical columns with values missing : ['MasVnrType', 'Electrical']

# %% [markdown]
# #### Quick exploration : categorical columns with missing values

# %%
#Plot distributions of categorical variables with missing values
plt.figure(figsize=(10, 20))

for i, column in enumerate(categorical_feat_missing, 1):
    plt.subplot(len(categorical_feat_missing), 1, i)    
    data[column].hist(bins = 50, figsize = (12,8))
    plt.title(f'Hist of {column}')
    plt.xlabel(column)
    plt.ylabel('Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Missing values : replace nans by 'most_frequent' (categorical cols)

# %% [markdown]
# **/!\ HUMAN INPUT FOR CHOOSING COLUMNS TO REPLACE NAN BY MOST_FREQUENT VALUE /!\**

# %%
# FULL STOP !!!!!!!!!!!

# %%
cat_columns_replace_by_most_frequent = ['MasVnrType', 'Electrical']
cat_columns_replace_by_most_frequent
# Out:
# ['MasVnrType', 'Electrical']

# %%
#Impute nans by most_frequent value in designated columns
for col in cat_columns_replace_by_most_frequent:
    print(f'--- {col} -----------------------------------------------\n')
    print(f'- Unique values of {col} : {data[col].unique()}\n')   
    
    print( '- Imputing np.nan by most_frequent value\n')     
    # Attribute : Electrical => #Replace NaN by most_frequent value
    imputer = SimpleImputer(strategy='most_frequent')
    data[col] =  imputer.fit_transform(data[[col]])
    data[col].value_counts()#Check count of each category
    
    print(f'- Unique values of {col} : {data[col].unique()}\n')   
    print(f'- Value_counts of {col} :\n') 
    print(data[col].value_counts())
    print('-----------------------------------------------------------')
# Out:
# --- MasVnrType -----------------------------------------------
#
# - Unique values of MasVnrType : ['BrkFace' 'None' 'Stone' 'BrkCmn' nan]
#
# - Imputing np.nan by most_frequent value
#
# - Unique values of MasVnrType : ['BrkFace' 'None' 'Stone' 'BrkCmn']
#
# - Value_counts of MasVnrType :
#
# None       872
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64
# -----------------------------------------------------------
# --- Electrical -----------------------------------------------
#
# - Unique values of Electrical : ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]
#
# - Imputing np.nan by most_frequent value
#
# - Unique values of Electrical : ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix']
#
# - Value_counts of Electrical :
#
# SBrkr    1335
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64
# -----------------------------------------------------------

# %%
# Remove processed columns from list of total categorical features with missing values
for col in cat_columns_replace_by_most_frequent:
    categorical_feat_missing.remove(col)
    
print(f"Length of Categorical features with missing values : {len(categorical_feat_missing)}")
print(f"Remaining categorical columns with values missing : {categorical_feat_missing}")
# Out:
# Length of Categorical features with missing values : 0
# Remaining categorical columns with values missing : []

# %% [markdown]
# ### Missing values : Numerical columns

# %%
#Numerical features with missing values
numerical_feat_missing = missing_values_df[missing_values_df.Type != 'object']['features'].values.tolist()

print(f"Length of Numerical features with missing values : {len(numerical_feat_missing)}\n")
print(f"Remaining Numerical columns with values missing : {numerical_feat_missing}")
# Out:
# Length of Numerical features with missing values : 3
#
# Remaining Numerical columns with values missing : ['LotFrontage', 'GarageYrBlt', 'MasVnrArea']

# %% [markdown]
# #### Missing values : drop numerical columns

# %% [markdown]
# **/!\ Check if NANs correspond to an actual value/ has a meaning within each column before dropping it.**

# %%
# Select NUMERICAL features with more than 90% of missing values => create a list
condition = (missing_values_df['Percent_missing'] > 90) & (missing_values_df['Type'] != 'object')
num_columns_missing_high = missing_values_df[condition]['features'].values.tolist()

print(f"Numerical columns with high rate of values missing : {num_columns_missing_high}")
# Out:
# Numerical columns with high rate of values missing : []

# %% [markdown]
# **/!\ Check if NANs correspond to an actual value/ has a meaning within each column before dropping it.**

# %% [markdown]
# **If nans do not represent something meaningful in the documentation of the features, we can drop it (if rate > 90%)**

# %%
# Nans in the following columns have a meaning. Do not drop the following columns !!!!!
# num_columns_missing_high.remove('xxx') #nans in Alley are meaningful. Do not drop 'Alley'

# Ratio of missing values is way too high, let's drop these features
data.drop(columns= num_columns_missing_high, inplace=True) 
data.head(1)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave    NA      Reg
#
#   LandContour Utilities LotConfig  ... 3SsnPorch ScreenPorch PoolArea Fence  \
# 0         Lvl    AllPub    Inside  ...         0           0        0    NA
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
#
# [1 rows x 78 columns]

# %%
# Remove dropped columns from list of total numerical features with missing values
for col in num_columns_missing_high:
    numerical_feat_missing.remove(col)
    
print(f"Length of Numerical features with missing values : {len(numerical_feat_missing)}\n")
print(f"Remaining numerical columns with values missing : {numerical_feat_missing}")
# Out:
# Length of Numerical features with missing values : 3
#
# Remaining numerical columns with values missing : ['LotFrontage', 'GarageYrBlt', 'MasVnrArea']

# %% [markdown]
# #### Quick exploration : numerical columns with missing values

# %%
#Plot distributions of numerical variables with missing values
plt.figure(figsize=(10, 20))

for i, column in enumerate(numerical_feat_missing, 1):
    plt.subplot(len(numerical_feat_missing), 1, i)    
    data[column].hist(bins = 50, figsize = (12,8))
    plt.title(f'Hist of {column}')
    plt.xlabel(column)
    plt.ylabel('Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Missing values : replace nans by 'mean_value' (numerical cols)

# %% [markdown]
# **/!\ HUMAN INPUT FOR CHOOSING COLUMNS TO REPLACE NAN BY MEAN VALUE /!\**

# %%
# FULL STOP !!!!!!!!!!!

# %%
#List the columns whose nans have to be replaced by mean_value
num_columns_replace_by_mean_value = ['LotFrontage']

# %%
#Impute nans by mean value in designated columns
for col in num_columns_replace_by_mean_value:
    print(f'--- {col} -----------------------------------------------\n')   
    print( '- Imputing np.nan by mean value\n')     
    #Replace NaN by mean value 
    imputer = SimpleImputer(strategy='mean')
    data[col] =  imputer.fit_transform(data[[col]])
    print('-----------------------------------------------------------')
# Out:
# --- LotFrontage -----------------------------------------------
#
# - Imputing np.nan by most_frequent value
#
# -----------------------------------------------------------

# %%
# Remove processed columns from list of total categorical features with missing values
for col in num_columns_replace_by_mean_value:
    numerical_feat_missing.remove(col)
    
print(f"Length of Numerical features with missing values : {len(numerical_feat_missing)}")
print(f"Remaining Numerical columns with values missing : {numerical_feat_missing}")
# Out:
# Length of Numerical features with missing values : 2
# Remaining Numerical columns with values missing : ['GarageYrBlt', 'MasVnrArea']

# %% [markdown]
# #### Missing values : replace nans by 'most_frequent' (numerical cols)

# %% [markdown]
# **/!\ HUMAN INPUT FOR CHOOSING COLUMNS TO REPLACE NAN BY MOST_FREQUENT VALUE /!\**

# %%
# FULL STOP !!!!!!!!!!!

# %%
#List the columns whose nans have to be replaced by most_frequent value
num_columns_replace_by_most_frequent = ['GarageYrBlt', 'MasVnrArea']

# %%
#Impute nans by most_frequent value in designated columns
for col in num_columns_replace_by_most_frequent:
    print(f'--- {col} -----------------------------------------------\n')
    print( '- Imputing np.nan by most_frequent value\n')     
    #Replace NaN by most_frequent value
    imputer = SimpleImputer(strategy='most_frequent')
    data[col] =  imputer.fit_transform(data[[col]])
    print('-----------------------------------------------------------')
# Out:
# --- GarageYrBlt -----------------------------------------------
#
# - Imputing np.nan by most_frequent value
#
# -----------------------------------------------------------
# --- MasVnrArea -----------------------------------------------
#
# - Imputing np.nan by most_frequent value
#
# -----------------------------------------------------------

# %%
# Remove processed columns from list of total categorical features with missing values
for col in num_columns_replace_by_most_frequent:
    numerical_feat_missing.remove(col)
    
print(f"Length of Numerical features with missing values : {len(numerical_feat_missing)}")
print(f"Remaining Numerical columns with values missing : {numerical_feat_missing}")
# Out:
# Length of Numerical features with missing values : 0
# Remaining Numerical columns with values missing : []

# %% [markdown]
# ### Final Check for missing values

# %%
# Counting the percentage of NaN for each column
#NaN percentage for each column
missing_data = data.isnull().sum().sort_values(ascending=False)/len(data)*100 
missing_data
# Out:
# MSSubClass     0.0
# HalfBath       0.0
# FireplaceQu    0.0
# Fireplaces     0.0
# Functional     0.0
#               ...
# MasVnrArea     0.0
# MasVnrType     0.0
# Exterior2nd    0.0
# Exterior1st    0.0
# SalePrice      0.0
# Length: 78, dtype: float64

# %% [markdown]
# ## Correlation check

# %% [markdown]
# - Correlations between features

# %%
# Correlation between features

correlation_matrix = data.corr()

# Converting the correlation matrix into a DataFrame
corr_df = correlation_matrix.stack().reset_index()

# Renaming the columns
corr_df.columns = ['feature_1','feature_2', 'correlation']

# Remove "self correlations"
no_self_correlation = (corr_df['feature_1'] != corr_df['feature_2'])
corr_df = corr_df[no_self_correlation]

corr_df['absolute_correlation'] = np.abs(corr_df['correlation'])

corr_df.sort_values(by="absolute_correlation", ascending=False, inplace = True)
corr_df
# Out:
#          feature_1     feature_2  correlation  absolute_correlation
# 951     GarageCars    GarageArea     0.882475              0.882475
# 987     GarageArea    GarageCars     0.882475              0.882475
# 577      GrLivArea  TotRmsAbvGrd     0.825489              0.825489
# 829   TotRmsAbvGrd     GrLivArea     0.825489              0.825489
# 419    TotalBsmtSF      1stFlrSF     0.819530              0.819530
# ...            ...           ...          ...                   ...
# 1143     3SsnPorch       MiscVal     0.000354              0.000354
# 640   BsmtHalfBath   TotalBsmtSF    -0.000315              0.000315
# 424    TotalBsmtSF  BsmtHalfBath    -0.000315              0.000315
# 1126     3SsnPorch  BsmtFullBath    -0.000106              0.000106
# 622   BsmtFullBath     3SsnPorch    -0.000106              0.000106
#
# [1332 rows x 4 columns]

# %% [markdown]
# - Correlation between target and features

# %%
# Correlation between target and features
target_name = "SalePrice"
corr_df[corr_df["feature_1"] == target_name].head(10)
# Out:
#       feature_1     feature_2  correlation  absolute_correlation
# 1335  SalePrice   OverallQual     0.790982              0.790982
# 1347  SalePrice     GrLivArea     0.708624              0.708624
# 1357  SalePrice    GarageCars     0.640409              0.640409
# 1358  SalePrice    GarageArea     0.623431              0.623431
# 1343  SalePrice   TotalBsmtSF     0.613581              0.613581
# 1344  SalePrice      1stFlrSF     0.605852              0.605852
# 1350  SalePrice      FullBath     0.560664              0.560664
# 1354  SalePrice  TotRmsAbvGrd     0.533723              0.533723
# 1337  SalePrice     YearBuilt     0.522897              0.522897
# 1338  SalePrice  YearRemodAdd     0.507101              0.507101

# %%
# Extract list of high correlated features to target
number_feat_to_extract = 6
extract_df = corr_df[corr_df["feature_1"] == target_name]\
                    .head(number_feat_to_extract)[['feature_2']]\
                    .values.tolist()

# Attributes
attributes = []

#Format a list with the attributes
for element in extract_df:
    attributes.append(element[0])

# Insert target in attributes
attributes.append(target_name)

# %%
#Plot scatter_matrix
scatter_matrix(data[attributes], figsize= (12,8))
plt.show()

# %% [markdown]
# ## Check outliers

# %%
#Retrieve all numerical columns in a list
numerical_columns = data.select_dtypes(include = np.number).columns.tolist()
numerical_columns.remove(target_name) #We don't take target into account on purpose

print(f"Length of Numerical columns : {len(numerical_columns)}\n")
print(f"Numerical columns : {numerical_columns}")
# Out:
# Length of Numerical columns : 36
#
# Numerical columns : ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %% [markdown]
# ### Explore outliers

# %%
# Plot the boxplot of the numerical features
plt.figure(figsize=(5, 80))

for i, column in enumerate(numerical_columns, 1):
    plt.subplot(len(numerical_columns), 1, i)    
    sns.boxplot(x=data[column], palette='Set2')
    plt.title(f'Boxplot of {column}')
    plt.xlabel(column)
    plt.ylabel('Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# **/!\ HUMAN INPUT FOR FINDING COLUMNS WITH OUTLIERS /!\**

# %%
# FULL STOP !!!!!!!!!!!

# %%
# Retrieve numerical features with outliers
numerical_columns_w_outliers = ['MSSubClass','LotFrontage','LotArea','OverallQual',
                                'OverallCond','YearBuilt','MasVnrArea','BsmtFinSF1',
                                'BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF',
                                '2ndFlrSF','LowQualFinSF','GrLivArea','BsmtFullBath',
                                'BsmtHalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd',
                                'Fireplaces','GarageYrBlt','GarageCars','GarageArea',
                                'WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch',
                                'ScreenPorch','PoolArea','MiscVal']

print(f"Length of Numerical columns WITH OUTLIERS : {len(numerical_columns_w_outliers)}\n")
# Out:
# Length of Numerical columns WITH OUTLIERS : 31

# %% [markdown]
# ### Implement Robust scaler

# %%
#Check statistics before robust scaling
data[numerical_columns_w_outliers].describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    22.024023    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    60.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    70.049958    9478.500000     6.000000     5.000000
# 75%      70.000000    79.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   103.117123   443.639726    46.549315   567.240411  ...
# std      30.202904   180.731373   456.098091   161.319273   441.866955  ...
# min    1872.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000     0.000000     0.000000     0.000000   223.000000  ...
# 50%    1973.000000     0.000000   383.500000     0.000000   477.500000  ...
# 75%    2000.000000   164.250000   712.250000     0.000000   808.000000  ...
# max    2010.000000  1600.000000  5644.000000  1474.000000  2336.000000  ...
#
#        GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1979.976027     1.767123   472.980137    94.244521    46.660274
# std      24.749688     0.747315   213.804841   125.338794    66.256028
# min    1900.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1962.000000     1.000000   334.500000     0.000000     0.000000
# 50%    1984.500000     2.000000   480.000000     0.000000    25.000000
# 75%    2003.000000     2.000000   576.000000   168.000000    68.000000
# max    2010.000000     4.000000  1418.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
# [8 rows x 31 columns]

# %%
#Instanciate, fit, transform
rb_scaler = RobustScaler()
data[numerical_columns_w_outliers] = rb_scaler.fit_transform(data[numerical_columns_w_outliers])

# %%
#Check statistics after robust scaling
data[numerical_columns_w_outliers].describe()
# Out:
#         MSSubClass   LotFrontage      LotArea  OverallQual  OverallCond  \
# count  1460.000000  1.460000e+03  1460.000000  1460.000000  1460.000000
# mean      0.137945 -2.895705e-16     0.256504     0.049658     0.575342
# std       0.846011  1.159159e+00     2.465728     0.691498     1.112799
# min      -0.600000 -2.581577e+00    -2.020380    -2.500000    -4.000000
# 25%      -0.600000 -5.289452e-01    -0.475543    -0.500000     0.000000
# 50%       0.000000  0.000000e+00     0.000000     0.000000     0.000000
# 75%       0.400000  4.710548e-01     0.524457     0.500000     1.000000
# max       2.800000  1.278684e+01    50.831645     2.000000     4.000000
#
#          YearBuilt   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean     -0.037656     0.627806     0.084436    46.549315     0.153402  ...
# std       0.656585     1.100343     0.640362   161.319273     0.755328  ...
# min      -2.195652     0.000000    -0.538435     0.000000    -0.816239  ...
# 25%      -0.413043     0.000000    -0.538435     0.000000    -0.435043  ...
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 75%       0.586957     1.000000     0.461565     0.000000     0.564957  ...
# max       0.804348     9.741248     7.385749  1474.000000     3.176923  ...
#
#        GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     -0.110341    -0.232877    -0.029068     0.560979     0.318533
# std       0.603651     0.747315     0.885320     0.746064     0.974353
# min      -2.060976    -2.000000    -1.987578     0.000000    -0.367647
# 25%      -0.548780    -1.000000    -0.602484     0.000000    -0.367647
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.451220     0.000000     0.397516     1.000000     0.632353
# max       0.621951     2.000000     3.884058     5.101190     7.676471
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ### Check columns with NO OUTLIERS

# %%
# Remove columns with ouliers from list of total numerical features
for col in numerical_columns_w_outliers:
    numerical_columns.remove(col)

numerical_columns_no_outliers = numerical_columns
    
print(f"Length of Numerical features with NO OUTLIERS : {len(numerical_columns_no_outliers)}\n")
print(f"Numerical features with NO OUTLIERS : {numerical_columns_no_outliers}")
# Out:
# Length of Numerical features with NO OUTLIERS : 5
#
# Numerical features with NO OUTLIERS : ['YearRemodAdd', 'FullBath', 'HalfBath', 'MoSold', 'YrSold']

# %%
# Plot the boxplot of the numerical features with NO OUTLIERS
plt.figure(figsize=(5, 10))

for i, column in enumerate(numerical_columns_no_outliers, 1):
    plt.subplot(len(numerical_columns), 1, i)    
    sns.boxplot(x=data[column], palette='Set2')
    plt.title(f'Boxplot of {column}')
    plt.xlabel(column)
    plt.ylabel('Value')

plt.tight_layout()
plt.show()

# %%
data[numerical_columns_no_outliers].describe()
# Out:
#        YearRemodAdd     FullBath     HalfBath       MoSold       YrSold
# count   1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    1984.865753     1.565068     0.382877     6.321918  2007.815753
# std       20.645407     0.550916     0.502885     2.703626     1.328095
# min     1950.000000     0.000000     0.000000     1.000000  2006.000000
# 25%     1967.000000     1.000000     0.000000     5.000000  2007.000000
# 50%     1994.000000     2.000000     0.000000     6.000000  2008.000000
# 75%     2004.000000     2.000000     1.000000     8.000000  2009.000000
# max     2010.000000     3.000000     2.000000    12.000000  2010.000000
